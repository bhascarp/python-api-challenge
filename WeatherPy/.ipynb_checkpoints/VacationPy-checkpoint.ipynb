# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
pip install Cartopy proj geoviews
# Out:
# Requirement already satisfied: Cartopy in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (0.22.0)
# Requirement already satisfied: proj in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (0.2.0)
# Requirement already satisfied: geoviews in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (1.11.0)
# Requirement already satisfied: numpy>=1.21 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from Cartopy) (1.24.3)
# Requirement already satisfied: matplotlib>=3.4 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from Cartopy) (3.8.0)
# Requirement already satisfied: shapely>=1.7 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from Cartopy) (2.0.2)
# Requirement already satisfied: packaging>=20 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from Cartopy) (23.1)
# Requirement already satisfied: pyshp>=2.1 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from Cartopy) (2.3.1)
# Requirement already satisfied: pyproj>=3.1.0 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from Cartopy) (3.6.1)
# Requirement already satisfied: arrow>=0.15.6 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from proj) (1.2.3)
# Requirement already satisfied: click>=7.1.2 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from proj) (8.1.7)
# Requirement already satisfied: bokeh<3.4.0,>=3.2.0 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from geoviews) (3.3.0)
# Requirement already satisfied: holoviews>=1.16.0 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from geoviews) (1.17.0)
# Requirement already satisfied: param in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from geoviews) (2.0.0)
# Requirement already satisfied: panel>=1.0.0 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from geoviews) (1.3.0)
# Requirement already satisfied: xyzservices in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from geoviews) (2022.9.0)
# Requirement already satisfied: python-dateutil>=2.7.0 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from arrow>=0.15.6->proj) (2.8.2)
# Requirement already satisfied: Jinja2>=2.9 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (3.1.2)
# Requirement already satisfied: contourpy>=1 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (1.0.5)
# Requirement already satisfied: pandas>=1.2 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (2.1.1)
# Requirement already satisfied: pillow>=7.1.0 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (10.0.1)
# Requirement already satisfied: PyYAML>=3.10 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (6.0.1)
# Requirement already satisfied: tornado>=5.1 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (6.3.3)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from holoviews>=1.16.0->geoviews) (2.3.0)
# Requirement already satisfied: colorcet in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from holoviews>=1.16.0->geoviews) (3.0.1)
# Requirement already satisfied: cycler>=0.10 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.4->Cartopy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.4->Cartopy) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.4->Cartopy) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.4->Cartopy) (3.0.9)
# Requirement already satisfied: markdown in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from panel>=1.0.0->geoviews) (3.4.1)
# Requirement already satisfied: markdown-it-py in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from panel>=1.0.0->geoviews) (2.2.0)
# Requirement already satisfied: linkify-it-py in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from panel>=1.0.0->geoviews) (2.0.0)
# Requirement already satisfied: mdit-py-plugins in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from panel>=1.0.0->geoviews) (0.3.0)
# Requirement already satisfied: requests in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from panel>=1.0.0->geoviews) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.0 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from panel>=1.0.0->geoviews) (4.65.0)
# Requirement already satisfied: bleach in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from panel>=1.0.0->geoviews) (4.1.0)
# Requirement already satisfied: typing-extensions in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from panel>=1.0.0->geoviews) (4.7.1)
# Requirement already satisfied: certifi in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from pyproj>=3.1.0->Cartopy) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from Jinja2>=2.9->bokeh<3.4.0,>=3.2.0->geoviews) (2.1.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from pandas>=1.2->bokeh<3.4.0,>=3.2.0->geoviews) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from pandas>=1.2->bokeh<3.4.0,>=3.2.0->geoviews) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7.0->arrow>=0.15.6->proj) (1.16.0)
# Requirement already satisfied: webencodings in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: pyct>=0.4.4 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from colorcet->holoviews>=1.16.0->geoviews) (0.5.0)
# Requirement already satisfied: uc-micro-py in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from linkify-it-py->panel>=1.0.0->geoviews) (1.0.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from markdown-it-py->panel>=1.0.0->geoviews) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from requests->panel>=1.0.0->geoviews) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from requests->panel>=1.0.0->geoviews) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/bhaskarpatil/anaconda3/lib/python3.11/site-packages (from requests->panel>=1.0.0->geoviews) (1.26.18)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  olonkinbyen  70.9221   -8.7187     -3.58        69         100
# 1        1   constantia  44.1833   28.6500      3.38        73           7
# 2        2    adamstown -25.0660 -130.1015     22.82        81         100
# 3        3    grytviken -54.2811  -36.5092      2.11        70          20
# 4        4      udachny  66.4167  112.4000    -28.48        96          80
#
#    Wind Speed Country        Date
# 0        3.58      SJ  1702956727
# 1        3.27      RO  1702956727
# 2        7.27      PN  1702956727
# 3        2.09      GS  1702956727
# 4        1.30      RU  1702956727

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot= city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 1,
    color = "City"
)

# Display the map
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
city_ideal_weather_df = city_data_df[(city_data_df['Max Temp']<27) & (city_data_df['Max Temp']>21) & (city_data_df['Wind Speed']<4.5) & (city_data_df['Cloudiness']==0)]

# Drop any rows with null values
city_ideal_weather_df = city_ideal_weather_df.dropna()

# Display sample data
city_ideal_weather_df.head()
# Out:
#      City_ID               City      Lat      Lng  Max Temp  Humidity  \
# 51        51            mukalla  14.5425  49.1242     22.65        36
# 86        86  sao joao da barra -21.6403 -41.0511     23.50        90
# 326      326    arraial do cabo -22.9661 -42.0278     23.24        90
# 360      360    remire-montjoly   4.9167 -52.2667     26.02        89
# 432      432             gwadar  25.1216  62.3254     21.81        52
#
#      Cloudiness  Wind Speed Country        Date
# 51            0        2.88      YE  1702956733
# 86            0        2.24      BR  1702956566
# 326           0        4.24      BR  1702956765
# 360           0        0.00      GF  1702956556
# 432           0        3.72      PK  1702956775

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_ideal_weather_df[['City','Country','Lat','Lng','Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name']= " "


# Display sample data
hotel_df.head(10)
# Out:
#                   City Country      Lat      Lng  Humidity Hotel Name
# 51             mukalla      YE  14.5425  49.1242        36
# 86   sao joao da barra      BR -21.6403 -41.0511        90
# 326    arraial do cabo      BR -22.9661 -42.0278        90
# 360    remire-montjoly      GF   4.9167 -52.2667        89
# 432             gwadar      PK  25.1216  62.3254        52

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000

params = {
    # YOUR CODE HERE
    "categories":'accommodation.hotel',
    "limit":20,
    "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# mukalla - nearest hotel: فندق الجابري
# sao joao da barra - nearest hotel: Pousada Mediterrâneo
# arraial do cabo - nearest hotel: No hotel found
# remire-montjoly - nearest hotel: Complexe Belova
# gwadar - nearest hotel: Sadaf Resorts
#                   City Country      Lat      Lng  Humidity  \
# 51             mukalla      YE  14.5425  49.1242        36
# 86   sao joao da barra      BR -21.6403 -41.0511        90
# 326    arraial do cabo      BR -22.9661 -42.0278        90
# 360    remire-montjoly      GF   4.9167 -52.2667        89
# 432             gwadar      PK  25.1216  62.3254        52
#
#                Hotel Name
# 51           فندق الجابري
# 86   Pousada Mediterrâneo
# 326        No hotel found
# 360       Complexe Belova
# 432         Sadaf Resorts

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 2,
    color = "City",
    hover_cols = ["Hotel Name", "Country"]
)

# Display the map
map_plot_2
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
